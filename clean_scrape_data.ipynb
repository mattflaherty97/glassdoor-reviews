# %% [markdown]
# # Clean Data
#
# In this notebook, we will be cleaning the scraped data. IF YOU HAVE NOT SCRAPED THE DATA, THEN THIS CODE WILL NOT WORK.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# load scraped data
company_reviews = pd.read_csv('./company_reviews.csv')
company_reviews.head()
# Out:
#                        company  rating  sub_work_life_balance  \
# 0  AMERICAN AIRLINES GROUP INC     5.0                    NaN
# 1  AMERICAN AIRLINES GROUP INC     3.0                    4.0
# 2  AMERICAN AIRLINES GROUP INC     5.0                    5.0
# 3  AMERICAN AIRLINES GROUP INC     1.0                    NaN
# 4  AMERICAN AIRLINES GROUP INC     3.0                    4.0
#
#    sub_culture_values  sub_diversity_inclusion  sub_career_opportunities  \
# 0                 NaN                      NaN                       NaN
# 1                 3.0                      5.0                       3.0
# 2                 5.0                      5.0                       5.0
# 3                 NaN                      NaN                       NaN
# 4                 2.0                      5.0                       3.0
#
#    sub_compensation_benefits  sub_senior_management  \
# 0                        NaN                    NaN
# 1                        3.0                    3.0
# 2                        5.0                    5.0
# 3                        NaN                    NaN
# 4                        3.0                    3.0
#
#                                          author_info  \
# 0                 Mar 15, 2022 - Customer Relations
# 1  Mar 15, 2022 - American Airlines Flight Attend...
# 2                   Mar 15, 2022 - Flight Attendant
# 3                              Mar 15, 2022 - Pilot
# 4  Mar 14, 2022 - Senior Project Manager in Fort ...
#
#                        employee_status  recommend  ceo_approval  outlook  \
# 0                     Current Employee          2             2        2
# 1  Current Employee, more than 5 years          1             4        3
# 2                     Current Employee          1             1        1
# 3                      Former Employee          2             2        2
# 4  Former Employee, more than 10 years          2             1        1
#
#                                                 pros  \
# 0                flexiblitiy is great amongest staff
# 1  Flexible schedules, great flight benefits, gre...
# 2  Love my job . Love the freedom not being micro...
# 3             Quit after one month with the company.
# 4  Resources love to stay with this company for d...
#
#                                                 cons  \
# 0             the work load is overwhelming at times
# 1  Constantly understaffed in all areas, Poor man...
# 2  Reserve reserve reserve not being able to hold...
# 3     Working conditions, customer service, Terrance
# 4  Retention of resources Didn’t seem important I...
#
#                                    advice_management
# 0                                                  0
# 1  Hire more people so we aren't constantly delay...
# 2                                                  0
# 3  Stop being a company full of uneducated low-li...
# 4  Offer retention bonuses for those loyal people...

# %%
'''clean columns'''

# extract information from 'author_info'
company_reviews['date'] = company_reviews['author_info'].str.split(' - ', n=1, expand=True)[[0]]
company_reviews['other_info'] = company_reviews['author_info'].str.split(' - ', n=1, expand=True)[[1]]
company_reviews['title'] = company_reviews['other_info'].str.split(' in ', n=1, expand=True)[[0]]
company_reviews['location'] = company_reviews['other_info'].str.split(' in ', n=1, expand=True)[[1]]
company_reviews['city'] = company_reviews['location'].str.split(', ', n=1, expand=True)[[0]]
company_reviews['state'] = company_reviews['location'].str.split(', ', n=1, expand=True)[[1]]

# extract information from 'employee status'
company_reviews['employee'] = company_reviews['employee_status'].str.split(', ', n=1, expand=True)[[0]]
company_reviews['years'] = company_reviews['employee_status'].str.split(', ', n=1, expand=True)[[1]]
company_reviews.loc[company_reviews.employee == 'Current Employee', 'current_employee'] = 1
company_reviews.loc[company_reviews.employee == 'Former Employee', 'current_employee'] = 0
company_reviews['years'] = company_reviews['years'].str.split(' ', expand=True)[[2]]

# drop columns
company_reviews.drop(['author_info', 'other_info', 'location', 'employee_status', 'employee'], inplace=True, axis=1)

# %%
# convert numbers used for symbols into words
for i,j in enumerate(['yes', np.nan, 'neutral', 'no']):
    company_reviews.loc[company_reviews.recommend == i+1, 'recommend'] = j
    company_reviews.loc[company_reviews.ceo_approval == i+1, 'ceo_approval'] = j
    company_reviews.loc[company_reviews.outlook == i+1, 'outlook'] = j

# %%
# combine pros, cons, and advice
company_reviews['advice_management'] = company_reviews['advice_management'].replace('0', '', regex=True)
company_reviews['advice_management'] = company_reviews['advice_management'].replace(np.nan, '', regex=True)
company_reviews['free_text_response'] = company_reviews['pros'] + ' ' + company_reviews['cons'] + ' ' + company_reviews['advice_management']
# company_reviews['free_text_response'] = company_reviews[['pros', 'cons', 'advice_management']].agg('. '.join, axis=1)
# company_reviews.drop(['pros', 'cons', 'advice_management'], inplace=True, axis=1)

# %%
# date from sting to date format
company_reviews['date'] = pd.to_datetime(company_reviews['date'])

# %%
company_reviews['year'] = company_reviews['date'].astype('str').str.split('-',expand=True)[0]
company_reviews['month'] = company_reviews['date'].astype('str').str.split('-',expand=True)[1]

# %%
company_reviews.head()
# Out:
#                        company  rating  sub_work_life_balance  \
# 0  AMERICAN AIRLINES GROUP INC     5.0                    NaN
# 1  AMERICAN AIRLINES GROUP INC     3.0                    4.0
# 2  AMERICAN AIRLINES GROUP INC     5.0                    5.0
# 3  AMERICAN AIRLINES GROUP INC     1.0                    NaN
# 4  AMERICAN AIRLINES GROUP INC     3.0                    4.0
#
#    sub_culture_values  sub_diversity_inclusion  sub_career_opportunities  \
# 0                 NaN                      NaN                       NaN
# 1                 3.0                      5.0                       3.0
# 2                 5.0                      5.0                       5.0
# 3                 NaN                      NaN                       NaN
# 4                 2.0                      5.0                       3.0
#
#    sub_compensation_benefits  sub_senior_management recommend ceo_approval  \
# 0                        NaN                    NaN       NaN          NaN
# 1                        3.0                    3.0       yes           no
# 2                        5.0                    5.0       yes          yes
# 3                        NaN                    NaN       NaN          NaN
# 4                        3.0                    3.0       NaN          yes
#
#    outlook                                               pros  \
# 0      NaN                flexiblitiy is great amongest staff
# 1  neutral  Flexible schedules, great flight benefits, gre...
# 2      yes  Love my job . Love the freedom not being micro...
# 3      NaN             Quit after one month with the company.
# 4      yes  Resources love to stay with this company for d...
#
#                                                 cons  \
# 0             the work load is overwhelming at times
# 1  Constantly understaffed in all areas, Poor man...
# 2  Reserve reserve reserve not being able to hold...
# 3     Working conditions, customer service, Terrance
# 4  Retention of resources Didn’t seem important I...
#
#                                    advice_management       date  \
# 0                                                    2022-03-15
# 1  Hire more people so we aren't constantly delay... 2022-03-15
# 2                                                    2022-03-15
# 3  Stop being a company full of uneducated low-li... 2022-03-15
# 4  Offer retention bonuses for those loyal people... 2022-03-14
#
#                                 title        city state years  \
# 0                 Customer Relations         None  None  None
# 1  American Airlines Flight Attendant    New York    NY     5
# 2                   Flight Attendant         None  None  None
# 3                              Pilot         None  None  None
# 4              Senior Project Manager  Fort Worth    TX    10
#
#    current_employee                                 free_text_response  year  \
# 0               1.0  flexiblitiy is great amongest staff the work l...  2022
# 1               1.0  Flexible schedules, great flight benefits, gre...  2022
# 2               1.0  Love my job . Love the freedom not being micro...  2022
# 3               0.0  Quit after one month with the company. Working...  2022
# 4               0.0  Resources love to stay with this company for d...  2022
#
#   month
# 0    03
# 1    03
# 2    03
# 3    03
# 4    03

# %%
# company_reviews.to_csv('C:/Users/19012/Documents/sp22-capstone/cleaned_reviews.csv', index=False)
